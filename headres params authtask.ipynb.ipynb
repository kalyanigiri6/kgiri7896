# %% [markdown]
# * find a website where you can pass parms ,header and auth

# %%
import requests as rq

# %%
url ='https://api.openaq.org/v2/countries'

# %%
rResp = rq.get(url)
rResp
# Out:
# <Response [200]>

# %%
decontent = rResp.content.decode('utf-8')

# %%
print(decontent)
# Out:
# {"meta":{"name":"openaq-api","license":"","website":"/","page":1,"limit":100,"found":">100"},"results":[{"code":"AF","name":"Afghanistan","locations":2,"firstUpdated":"2019-10-20 22:30:00+00","lastUpdated":"2021-08-16 18:00:00+00","parameters":["pm25"],"count":23640,"cities":1,"sources":2},{"code":"DZ","name":"Algeria","locations":1,"firstUpdated":"2019-06-15 22:00:00+00","lastUpdated":"2024-05-31 18:00:00+00","parameters":["pm25"],"count":38747,"cities":1,"sources":1},{"code":"AQ","name":"Antarctica","locations":2,"firstUpdated":"2018-11-30 11:00:00+00","lastUpdated":"2021-02-04 14:00:00+00","parameters":["co","no2","o3","pm10","pm25","so2"],"count":9180,"cities":0,"sources":2},{"code":"AR","name":"Argentina","locations":17,"firstUpdated":"2016-01-01 03:00:00+00","lastUpdated":"2024-05-31 18:00:00+00","parameters":["co","no","no2","nox","o3","pm1","pm10","pm25","relativehumidity","so2","temperature","um003"],"count":290118,"cities":1,"sources":6},{"code":"AM","name":"Armenia","locations":1,"firstUpdated":"2022-11-14 08:00:00+00","lastUpdated":"2023-06-15 11:00:00+00","parameters":["pm25"],"count":1284,"cities":1,"sources":1},{"code":"AU","name":"Australia","locations":244,"firstUpdated":"2016-01-28 19:00:00+00","lastUpdated":"2024-05-31 18:24:08+00","parameters":["co","no2","o3","pm1","pm10","pm25","relativehumidity","so2","temperature","um003"],"count":13897588,"cities":55,"sources":10},{"code":"AT","name":"Austria","locations":375,"firstUpdated":"2016-11-18 05:00:00+00","lastUpdated":"2024-05-31 17:00:00+00","parameters":["co","no","no2","o3","pm1","pm10","pm25","relativehumidity","so2","temperature","um003"],"count":13439969,"cities":162,"sources":4},{"code":"AZ","name":"Azerbaijan","locations":1,"firstUpdated":"2022-06-23 12:00:00+00","lastUpdated":"2024-05-31 16:00:00+00","parameters":["pm25"],"count":12869,"cities":1,"sources":1},{"code":"BD","name":"Bangladesh","locations":4,"firstUpdated":"2016-03-10 22:00:00+00","lastUpdated":"2024-05-31 17:00:00+00","parameters":["co","no2","o3","pm10","pm25","so2"],"count":139723,"cities":1,"sources":3},{"code":"BE","name":"Belgium","locations":174,"firstUpdated":"2016-01-30 01:00:00+00","lastUpdated":"2024-05-31 17:00:00+00","parameters":["co","no","no2","o3","pm1","pm10","pm25","relativehumidity","so2","temperature","um003"],"count":4789164,"cities":77,"sources":6},{"code":"BZ","name":"Belize","locations":1,"firstUpdated":"2023-03-19 20:00:00+00","lastUpdated":"2024-05-31 17:00:00+00","parameters":["pm25"],"count":8028,"cities":1,"sources":1},{"code":"BA","name":"Bosnia and Herz.","locations":47,"firstUpdated":"2016-04-26 21:30:00+00","lastUpdated":"2024-05-31 18:00:00+00","parameters":["co","no2","o3","pm1","pm10","pm25","relativehumidity","so2","temperature","um003"],"count":1360097,"cities":22,"sources":6},{"code":"BR","name":"Brazil","locations":75,"firstUpdated":"2017-07-01 00:00:00+00","lastUpdated":"2024-05-31 18:00:00+00","parameters":["co","humidity","no","no2","nox","o3","pm1","pm10","pm25","pressure","so2","temperature","um003","um005","um010","um025","um050","um100","voc"],"count":3057628,"cities":39,"sources":5},{"code":"BG","name":"Bulgaria","locations":105,"firstUpdated":"2020-04-20 18:00:00+00","lastUpdated":"2024-05-31 18:44:00+00","parameters":["co","humidity","no","no2","o3","pm1","pm10","pm25","pm4","pressure","so2","temperature"],"count":127889965,"cities":2,"sources":2},{"code":"CA","name":"Canada","locations":366,"firstUpdated":"2016-03-06 19:00:00+00","lastUpdated":"2024-05-31 18:06:18.647+00","parameters":["co","no","no2","nox","o3","pm1","pm10","pm25","relativehumidity","so2","temperature","um003"],"count":18394401,"cities":18,"sources":5},{"code":"TD","name":"Chad","locations":1,"firstUpdated":"2020-08-02 20:00:00+00","lastUpdated":"2024-05-31 18:00:00+00","parameters":["pm25"],"count":29073,"cities":1,"sources":1},{"code":"CL","name":"Chile","locations":154,"firstUpdated":"2016-01-30 01:00:00+00","lastUpdated":"2024-05-31 17:00:00+00","parameters":["co ...

# %%
rResp.json()
# Out:
# {'meta': {'name': 'openaq-api',
#   'license': '',
#   'website': '/',
#   'page': 1,
#   'limit': 100,
#   'found': '>100'},
#  'results': [{'code': 'AF',
#    'name': 'Afghanistan',
#    'locations': 2,
#    'firstUpdated': '2019-10-20 22:30:00+00',
#    'lastUpdated': '2021-08-16 18:00:00+00',
#    'parameters': ['pm25'],
#    'count': 23640,
#    'cities': 1,
#    'sources': 2},
#   {'code': 'DZ',
#    'name': 'Algeria',
#    'locations': 1,
#    'firstUpdated': '2019-06-15 22:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['pm25'],
#    'count': 38747,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'AQ',
#    'name': 'Antarctica',
#    'locations': 2,
#    'firstUpdated': '2018-11-30 11:00:00+00',
#    'lastUpdated': '2021-02-04 14:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 9180,
#    'cities': 0,
#    'sources': 2},
#   {'code': 'AR',
#    'name': 'Argentina',
#    'locations': 17,
#    'firstUpdated': '2016-01-01 03:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'nox',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 290118,
#    'cities': 1,
#    'sources': 6},
#   {'code': 'AM',
#    'name': 'Armenia',
#    'locations': 1,
#    'firstUpdated': '2022-11-14 08:00:00+00',
#    'lastUpdated': '2023-06-15 11:00:00+00',
#    'parameters': ['pm25'],
#    'count': 1284,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'AU',
#    'name': 'Australia',
#    'locations': 244,
#    'firstUpdated': '2016-01-28 19:00:00+00',
#    'lastUpdated': '2024-05-31 18:24:08+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 13897588,
#    'cities': 55,
#    'sources': 10},
#   {'code': 'AT',
#    'name': 'Austria',
#    'locations': 375,
#    'firstUpdated': '2016-11-18 05:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 13439969,
#    'cities': 162,
#    'sources': 4},
#   {'code': 'AZ',
#    'name': 'Azerbaijan',
#    'locations': 1,
#    'firstUpdated': '2022-06-23 12:00:00+00',
#    'lastUpdated': '2024-05-31 16:00:00+00',
#    'parameters': ['pm25'],
#    'count': 12869,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'BD',
#    'name': 'Bangladesh',
#    'locations': 4,
#    'firstUpdated': '2016-03-10 22:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 139723,
#    'cities': 1,
#    'sources': 3},
#   {'code': 'BE',
#    'name': 'Belgium',
#    'locations': 174,
#    'firstUpdated': '2016-01-30 01:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 4789164,
#    'cities': 77,
#    'sources': 6},
#   {'code': 'BZ',
#    'name': 'Belize',
#    'locations': 1,
#    'firstUpdated': '2023-03-19 20:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['pm25'],
#    'count': 8028,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'BA',
#    'name': 'Bosnia and Herz.',
#    'locations': 47,
#    'firstUpdated': '2016-04-26 21:30:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 1360097,
#    'cities': 22,
#    'sources': 6},
#   {'code': 'BR',
#    'name': 'Brazil',
#    'locations': 75,
#    'firstUpdated': '2017-07-01 00:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co',
#     'humidity',
#     'no',
#     'no2',
#     'nox',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'pressure',
#     'so2',
#     'temperature',
#     'um003',
#     'um005',
#     'um010',
#     'um025',
#     'um050',
#     'um100',
#     'voc'],
#    'count': 3057628,
#    'cities': 39,
#    'sources': 5},
#   {'code': 'BG',
#    'name': 'Bulgaria',
#    'locations': 105,
#    'firstUpdated': '2020-04-20 18:00:00+00',
#    'lastUpdated': '2024-05-31 18:44:00+00',
#    'parameters': ['co',
#     'humidity',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'pm4',
#     'pressure',
#     'so2',
#     'temperature'],
#    'count': 127889965,
#    'cities': 2,
#    'sources': 2},
#   {'code': 'CA',
#    'name': 'Canada',
#    'locations': 366,
#    'firstUpdated': '2016-03-06 19:00:00+00',
#    'lastUpdated': '2024-05-31 18:06:18.647+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'nox',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 18394401,
#    'cities': 18,
#    'sources': 5},
#   {'code': 'TD',
#    'name': 'Chad',
#    'locations': 1,
#    'firstUpdated': '2020-08-02 20:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['pm25'],
#    'count': 29073,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'CL',
#    'name': 'Chile',
#    'locations': 154,
#    'firstUpdated': '2016-01-30 01:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 10847919,
#    'cities': 61,
#    'sources': 2},
#   {'code': 'CN',
#    'name': 'China',
#    'locations': 1873,
#    'firstUpdated': '2016-01-01 01:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 170596157,
#    'cities': 18,
#    'sources': 19},
#   {'code': 'CO',
#    'name': 'Colombia',
#    'locations': 60,
#    'firstUpdated': '2016-03-17 15:00:00+00',
#    'lastUpdated': '2024-05-31 18:05:11.963+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 2419898,
#    'cities': 10,
#    'sources': 5},
#   {'code': 'CR',
#    'name': 'Costa Rica',
#    'locations': 1,
#    'firstUpdated': '2019-10-28 18:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['pm25'],
#    'count': 33197,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'CI',
#    'name': "Côte d'Ivoire",
#    'locations': 1,
#    'firstUpdated': '2020-03-15 21:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['pm25'],
#    'count': 29814,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'HR',
#    'name': 'Croatia',
#    'locations': 27,
#    'firstUpdated': '2016-11-17 22:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 1505384,
#    'cities': 16,
#    'sources': 3},
#   {'code': 'CY',
#    'name': 'Cyprus',
#    'locations': 11,
#    'firstUpdated': '2020-04-20 16:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co', 'no', 'no2', 'nox', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 654077,
#    'cities': 11,
#    'sources': 2},
#   {'code': 'CZ',
#    'name': 'Czechia',
#    'locations': 124,
#    'firstUpdated': '2016-11-21 11:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 11850910,
#    'cities': 72,
#    'sources': 4},
#   {'code': 'CD',
#    'name': 'Dem. Rep. Congo',
#    'locations': 1,
#    'firstUpdated': '2022-06-16 16:00:00+00',
#    'lastUpdated': '2024-05-31 10:00:00+00',
#    'parameters': ['pm25'],
#    'count': 3812,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'DK',
#    'name': 'Denmark',
#    'locations': 15,
#    'firstUpdated': '2016-11-21 11:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm10',
#     'pm25',
#     'so2',
#     'temperature'],
#    'count': 1046875,
#    'cities': 9,
#    'sources': 3},
#   {'code': 'EC',
#    'name': 'Ecuador',
#    'locations': 10,
#    'firstUpdated': '2020-12-29 05:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 94237,
#    'cities': 0,
#    'sources': 2},
#   {'code': 'EG',
#    'name': 'Egypt',
#    'locations': 2,
#    'firstUpdated': '2022-06-20 18:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['pm25'],
#    'count': 10944,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'EE',
#    'name': 'Estonia',
#    'locations': 7,
#    'firstUpdated': '2020-04-20 20:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 259008,
#    'cities': 5,
#    'sources': 1},
#   {'code': 'ET',
#    'name': 'Ethiopia',
#    'locations': 3,
#    'firstUpdated': '2016-08-18 22:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['pm25'],
#    'count': 113926,
#    'cities': 2,
#    'sources': 2},
#   {'code': 'FI',
#    'name': 'Finland',
#    'locations': 81,
#    'firstUpdated': '2016-12-10 19:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 4450330,
#    'cities': 32,
#    'sources': 2},
#   {'code': 'FR',
#    'name': 'France',
#    'locations': 793,
#    'firstUpdated': '2016-11-17 23:00:00+00',
#    'lastUpdated': '2024-05-31 18:02:01.284+00',
#    'parameters': ['co',
#     'humidity',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'pressure',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003',
#     'um005',
#     'um010',
#     'um025',
#     'um050',
#     'um100'],
#    'count': 46357815,
#    'cities': 418,
#    'sources': 8},
#   {'code': 'GA',
#    'name': 'Gabon',
#    'locations': 1,
#    'firstUpdated': '2021-10-06 12:00:00+00',
#    'lastUpdated': '2022-02-27 19:00:00+00',
#    'parameters': ['pm25'],
#    'count': 2828,
#    'cities': 0,
#    'sources': 1},
#   {'code': 'GM',
#    'name': 'Gambia',
#    'locations': 1,
#    'firstUpdated': '2022-10-20 01:00:00+00',
#    'lastUpdated': '2023-09-15 23:03:55.489+00',
#    'parameters': ['no2', 'pm1', 'pm10', 'pm25'],
#    'count': 12354,
#    'cities': 0,
#    'sources': 1},
#   {'code': 'DE',
#    'name': 'Germany',
#    'locations': 514,
#    'firstUpdated': '2016-01-30 01:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 24141437,
#    'cities': 291,
#    'sources': 4},
#   {'code': 'GH',
#    'name': 'Ghana',
#    'locations': 12,
#    'firstUpdated': '2020-05-01 01:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['no2',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 1170945,
#    'cities': 1,
#    'sources': 3},
#   {'code': 'GR',
#    'name': 'Greece',
#    'locations': 52,
#    'firstUpdated': '2020-04-20 18:00:00+00',
#    'lastUpdated': '2024-05-31 18:44:00+00',
#    'parameters': ['co',
#     'humidity',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'pm4',
#     'pressure',
#     'so2',
#     'temperature'],
#    'count': 7458599,
#    'cities': 8,
#    'sources': 3},
#   {'code': 'GT',
#    'name': 'Guatemala',
#    'locations': 2,
#    'firstUpdated': '2019-10-20 21:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['o3', 'pm10', 'pm25'],
#    'count': 96351,
#    'cities': 2,
#    'sources': 2},
#   {'code': 'GN',
#    'name': 'Guinea',
#    'locations': 1,
#    'firstUpdated': '2020-05-01 02:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['pm25'],
#    'count': 28481,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'HU',
#    'name': 'Hungary',
#    'locations': 97,
#    'firstUpdated': '2016-12-12 14:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 5717102,
#    'cities': 64,
#    'sources': 3},
#   {'code': 'IS',
#    'name': 'Iceland',
#    'locations': 24,
#    'firstUpdated': '2020-02-28 01:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 829455,
#    'cities': 8,
#    'sources': 3},
#   {'code': 'IN',
#    'name': 'India',
#    'locations': 421,
#    'firstUpdated': '2016-01-30 00:30:00+00',
#    'lastUpdated': '2024-05-31 17:30:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 42138688,
#    'cities': 3,
#    'sources': 10},
#   {'code': 'ID',
#    'name': 'Indonesia',
#    'locations': 12,
#    'firstUpdated': '2016-01-30 01:00:00+00',
#    'lastUpdated': '2024-05-31 18:04:49.524+00',
#    'parameters': ['o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 140133,
#    'cities': 2,
#    'sources': 7},
#   {'code': 'IQ',
#    'name': 'Iraq',
#    'locations': 5,
#    'firstUpdated': '2019-03-10 16:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 71317,
#    'cities': 3,
#    'sources': 3},
#   {'code': 'IE',
#    'name': 'Ireland',
#    'locations': 45,
#    'firstUpdated': '2016-02-27 21:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 1696777,
#    'cities': 5,
#    'sources': 4},
#   {'code': 'IL',
#    'name': 'Israel',
#    'locations': 111,
#    'firstUpdated': '2016-01-01 01:00:00+00',
#    'lastUpdated': '2021-11-19 09:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm25', 'so2'],
#    'count': 19575369,
#    'cities': 1,
#    'sources': 2},
#   {'code': 'IT',
#    'name': 'Italy',
#    'locations': 746,
#    'firstUpdated': '2016-11-21 12:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'nox',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 25631256,
#    'cities': 600,
#    'sources': 8},
#   {'code': 'JP',
#    'name': 'Japan',
#    'locations': 1539,
#    'firstUpdated': '2023-07-14 17:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co', 'no', 'no2', 'nox', 'pm25', 'so2', 'temperature'],
#    'count': 38208605,
#    'cities': 1,
#    'sources': 3},
#   {'code': 'JO',
#    'name': 'Jordan',
#    'locations': 5,
#    'firstUpdated': '2017-08-10 23:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm25', 'so2'],
#    'count': 648902,
#    'cities': 2,
#    'sources': 3},
#   {'code': 'KZ',
#    'name': 'Kazakhstan',
#    'locations': 40,
#    'firstUpdated': '2018-07-27 16:00:00+00',
#    'lastUpdated': '2024-05-31 18:06:42.055+00',
#    'parameters': ['pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 149306,
#    'cities': 1,
#    'sources': 3},
#   {'code': 'KE',
#    'name': 'Kenya',
#    'locations': 6,
#    'firstUpdated': '2018-04-21 00:00:00+00',
#    'lastUpdated': '2024-05-31 18:01:10.061+00',
#    'parameters': ['pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 21490,
#    'cities': 1,
#    'sources': 4},
#   {'code': 'XK',
#    'name': 'Kosovo',
#    'locations': 24,
#    'firstUpdated': '2016-04-08 20:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 612958,
#    'cities': 12,
#    'sources': 4},
#   {'code': 'KW',
#    'name': 'Kuwait',
#    'locations': 1,
#    'firstUpdated': '2017-02-17 21:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['pm25'],
#    'count': 54958,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'KG',
#    'name': 'Kyrgyzstan',
#    'locations': 47,
#    'firstUpdated': '2019-03-08 20:00:00+00',
#    'lastUpdated': '2024-05-31 18:06:33.546+00',
#    'parameters': ['pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 188493,
#    'cities': 2,
#    'sources': 4},
#   {'code': 'LA',
#    'name': 'Laos',
#    'locations': 9,
#    'firstUpdated': '2021-04-29 19:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 227986,
#    'cities': 4,
#    'sources': 3},
#   {'code': 'LV',
#    'name': 'Latvia',
#    'locations': 13,
#    'firstUpdated': '2017-09-22 10:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 430248,
#    'cities': 5,
#    'sources': 2},
#   {'code': 'LT',
#    'name': 'Lithuania',
#    'locations': 17,
#    'firstUpdated': '2017-09-21 23:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 924030,
#    'cities': 13,
#    'sources': 2},
#   {'code': 'LU',
#    'name': 'Luxembourg',
#    'locations': 12,
#    'firstUpdated': '2017-09-22 10:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co', 'no', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 870723,
#    'cities': 1,
#    'sources': 2},
#   {'code': 'MK',
#    'name': 'Macedonia',
#    'locations': 28,
#    'firstUpdated': '2016-12-10 20:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co', 'no', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 2972749,
#    'cities': 6,
#    'sources': 2},
#   {'code': 'MG',
#    'name': 'Madagascar',
#    'locations': 1,
#    'firstUpdated': '2020-12-22 06:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['pm25'],
#    'count': 21959,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'MY',
#    'name': 'Malaysia',
#    'locations': 11,
#    'firstUpdated': '2016-04-05 09:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 115827,
#    'cities': 4,
#    'sources': 4},
#   {'code': 'ML',
#    'name': 'Mali',
#    'locations': 1,
#    'firstUpdated': '2020-03-16 05:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['pm25'],
#    'count': 25555,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'MX',
#    'name': 'Mexico',
#    'locations': 237,
#    'firstUpdated': '2016-03-06 19:00:00+00',
#    'lastUpdated': '2024-05-31 19:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'nox',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 10851220,
#    'cities': 111,
#    'sources': 4},
#   {'code': 'MD',
#    'name': 'Moldova',
#    'locations': 2,
#    'firstUpdated': '2020-04-20 19:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['no2', 'pm10', 'pm25', 'so2'],
#    'count': 35574,
#    'cities': 2,
#    'sources': 2},
#   {'code': 'MN',
#    'name': 'Mongolia',
#    'locations': 44,
#    'firstUpdated': '2016-01-30 00:15:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 2359003,
#    'cities': 23,
#    'sources': 4},
#   {'code': 'ME',
#    'name': 'Montenegro',
#    'locations': 9,
#    'firstUpdated': '2022-03-24 14:00:00+00',
#    'lastUpdated': '2024-03-19 22:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 273080,
#    'cities': 7,
#    'sources': 1},
#   {'code': 'MA',
#    'name': 'Morocco',
#    'locations': 2,
#    'firstUpdated': '2024-04-04 10:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 8904,
#    'cities': 0,
#    'sources': 1},
#   {'code': 'MZ',
#    'name': 'Mozambique',
#    'locations': 1,
#    'firstUpdated': '2024-01-18 18:00:00+00',
#    'lastUpdated': '2024-01-22 16:00:00+00',
#    'parameters': ['o3', 'pm25'],
#    'count': 137,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'MM',
#    'name': 'Myanmar',
#    'locations': 5,
#    'firstUpdated': '2016-01-30 01:00:00+00',
#    'lastUpdated': '2024-05-31 17:30:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 320480,
#    'cities': 3,
#    'sources': 4},
#   {'code': 'NP',
#    'name': 'Nepal',
#    'locations': 4,
#    'firstUpdated': '2017-03-02 23:15:00+00',
#    'lastUpdated': '2024-05-31 17:15:00+00',
#    'parameters': ['o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 222873,
#    'cities': 2,
#    'sources': 3},
#   {'code': 'NL',
#    'name': 'Netherlands',
#    'locations': 98,
#    'firstUpdated': '2016-01-30 01:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 13101369,
#    'cities': 50,
#    'sources': 4},
#   {'code': 'NZ',
#    'name': 'New Zealand',
#    'locations': 12,
#    'firstUpdated': '2023-03-31 15:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 99171,
#    'cities': 8,
#    'sources': 2},
#   {'code': 'NG',
#    'name': 'Nigeria',
#    'locations': 5,
#    'firstUpdated': '2019-04-26 08:00:00+00',
#    'lastUpdated': '2024-05-31 18:05:12.654+00',
#    'parameters': ['pm25'],
#    'count': 23730,
#    'cities': 2,
#    'sources': 3},
#   {'code': 'KP',
#    'name': 'North Korea',
#    'locations': 4,
#    'firstUpdated': '2024-03-20 08:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 30243,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'NO',
#    'name': 'Norway',
#    'locations': 354,
#    'firstUpdated': '2016-12-02 10:00:00+00',
#    'lastUpdated': '2024-05-31 18:44:00+00',
#    'parameters': ['bc',
#     'co',
#     'co2',
#     'humidity',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'pm4',
#     'pressure',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003',
#     'um005',
#     'um010',
#     'um025',
#     'um050',
#     'um100'],
#    'count': 36187746,
#    'cities': 27,
#    'sources': 5},
#   {'code': 'PK',
#    'name': 'Pakistan',
#    'locations': 6,
#    'firstUpdated': '2019-05-22 22:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['pm25'],
#    'count': 168687,
#    'cities': 4,
#    'sources': 5},
#   {'code': 'PS',
#    'name': 'Palestine',
#    'locations': 9,
#    'firstUpdated': '2017-08-10 23:00:00+00',
#    'lastUpdated': '2019-04-03 21:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'so2'],
#    'count': 1449100,
#    'cities': 0,
#    'sources': 1},
#   {'code': 'PY',
#    'name': 'Paraguay',
#    'locations': 1,
#    'firstUpdated': '2023-10-02 19:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['pm25'],
#    'count': 5128,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'PE',
#    'name': 'Peru',
#    'locations': 46,
#    'firstUpdated': '2016-03-04 17:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 2363656,
#    'cities': 21,
#    'sources': 5},
#   {'code': 'PH',
#    'name': 'Philippines',
#    'locations': 5,
#    'firstUpdated': '2023-09-06 20:00:00+00',
#    'lastUpdated': '2024-05-31 18:02:44.129+00',
#    'parameters': ['pm25', 'temperature'],
#    'count': 12900,
#    'cities': 1,
#    'sources': 3},
#   {'code': 'PL',
#    'name': 'Poland',
#    'locations': 331,
#    'firstUpdated': '2016-01-30 01:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['bc',
#     'co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 25858549,
#    'cities': 197,
#    'sources': 5},
#   {'code': 'PT',
#    'name': 'Portugal',
#    'locations': 70,
#    'firstUpdated': '2017-05-11 08:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 6864465,
#    'cities': 8,
#    'sources': 3},
#   {'code': 'PR',
#    'name': 'Puerto Rico',
#    'locations': 5,
#    'firstUpdated': '2016-05-04 11:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['o3', 'pm10', 'pm25'],
#    'count': 99760,
#    'cities': 2,
#    'sources': 1},
#   {'code': 'QA',
#    'name': 'Qatar',
#    'locations': 1,
#    'firstUpdated': '2022-04-11 14:00:00+00',
#    'lastUpdated': '2023-11-30 08:00:00+00',
#    'parameters': ['o3', 'pm25'],
#    'count': 16513,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'RO',
#    'name': 'Romania',
#    'locations': 318,
#    'firstUpdated': '2020-04-19 21:00:00+00',
#    'lastUpdated': '2024-05-31 18:06:38.617+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 5275200,
#    'cities': 109,
#    'sources': 4},
#   {'code': 'RU',
#    'name': 'Russia',
#    'locations': 54,
#    'firstUpdated': '2016-11-21 11:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 561138,
#    'cities': 2,
#    'sources': 5},
#   {'code': 'RW',
#    'name': 'Rwanda',
#    'locations': 2,
#    'firstUpdated': '2020-12-28 22:45:00+00',
#    'lastUpdated': '2024-05-14 00:00:00+00',
#    'parameters': ['co', 'no2', 'pm10', 'pm25'],
#    'count': 126004,
#    'cities': 1,
#    'sources': 2},
#   {'code': 'SA',
#    'name': 'Saudi Arabia',
#    'locations': 5,
#    'firstUpdated': '2019-07-15 19:00:00+00',
#    'lastUpdated': '2024-05-31 00:00:00+00',
#    'parameters': ['co', 'no2', 'pm10', 'pm25', 'so2'],
#    'count': 21342,
#    'cities': 3,
#    'sources': 3},
#   {'code': 'SN',
#    'name': 'Senegal',
#    'locations': 1,
#    'firstUpdated': '2023-09-05 08:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 7574,
#    'cities': 0,
#    'sources': 1},
#   {'code': 'RS',
#    'name': 'Serbia',
#    'locations': 85,
#    'firstUpdated': '2017-09-22 09:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2', 'temperature'],
#    'count': 3327150,
#    'cities': 44,
#    'sources': 5},
#   {'code': 'SK',
#    'name': 'Slovakia',
#    'locations': 85,
#    'firstUpdated': '2016-11-18 05:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co', 'no', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 5938390,
#    'cities': 58,
#    'sources': 3},
#   {'code': 'SI',
#    'name': 'Slovenia',
#    'locations': 39,
#    'firstUpdated': '2016-11-17 22:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 793207,
#    'cities': 26,
#    'sources': 3},
#   {'code': 'ZA',
#    'name': 'South Africa',
#    'locations': 200,
#    'firstUpdated': '2016-02-14 08:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'nox',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 4691551,
#    'cities': 36,
#    'sources': 4},
#   {'code': 'KR',
#    'name': 'South Korea',
#    'locations': 686,
#    'firstUpdated': '2020-10-12 06:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 6431385,
#    'cities': 3,
#    'sources': 3},
#   {'code': 'ES',
#    'name': 'Spain',
#    'locations': 738,
#    'firstUpdated': '2016-11-17 23:00:00+00',
#    'lastUpdated': '2024-05-31 18:44:00+00',
#    'parameters': ['co',
#     'humidity',
#     'no',
#     'no2',
#     'nox',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'pm4',
#     'pressure',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 45040033,
#    'cities': 352,
#    'sources': 7},
#   {'code': 'LK',
#    'name': 'Sri Lanka',
#    'locations': 1,
#    'firstUpdated': '2019-06-25 21:30:00+00',
#    'lastUpdated': '2024-05-30 18:30:00+00',
#    'parameters': ['pm25'],
#    'count': 21875,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'SD',
#    'name': 'Sudan',
#    'locations': 3,
#    'firstUpdated': '2020-05-14 14:00:00+00',
#    'lastUpdated': '2023-05-17 13:00:00+00',
#    'parameters': ['pm25'],
#    'count': 54546,
#    'cities': 2,
#    'sources': 3},
#   {'code': 'SE',
#    'name': 'Sweden',
#    'locations': 170,
#    'firstUpdated': '2016-12-02 11:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co', 'no', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 2549561,
#    'cities': 53,
#    'sources': 5},
#   {'code': 'CH',
#    'name': 'Switzerland',
#    'locations': 51,
#    'firstUpdated': '2016-11-21 12:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 3298540,
#    'cities': 13,
#    'sources': 3},
#   {'code': 'TW',
#    'name': 'Taiwan',
#    'locations': 91,
#    'firstUpdated': '2016-12-20 19:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 8405956,
#    'cities': 17,
#    'sources': 2}]}

# %% [markdown]
# # Headres

# %%
type(rResp.headers)

lHeader = rResp.headers

print(lHeader)
# Out:
# {'Content-Type': 'application/json', 'Content-Length': '3391', 'Connection': 'keep-alive', 'Date': 'Fri, 31 May 2024 18:46:59 GMT', 'Ratelimit-Reset': '60', 'Ratelimit-Policy': '3;w=60', 'Cache-Control': 'public, max-age=900', 'Content-Encoding': 'gzip', 'Ratelimit-Limit': '3', 'Ratelimit-Remaining': '2', 'Apigw-Requestid': 'YpktliY9oAMEY3Q=', 'Vary': 'Accept-Encoding', 'X-Cache': 'Miss from cloudfront', 'Via': '1.1 59e53eee287aef894f734cb99479a91c.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'HYD57-P4', 'X-Amz-Cf-Id': 'auiBMEb_-owz2bQY22WmiG06xhNJJJhKCIvhVIt43Anr6AjaxChRbg=='}

# %%
print(f'Content-Type = {lHeader["Content-Type"]}')

print(f'Date = {lHeader["Date"]}')
# Out:
# Content-Type = application/json
# Date = Fri, 31 May 2024 18:46:59 GMT

# %%
userAgent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'

# %%
cHeader = rq.get(url, headers= {'User-Agent': userAgent })
print(cHeader)
# Out:
# <Response [200]>

# %%
cHeader.request.headers
# Out:
# {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)', 'Accept-Encoding': 'gzip, deflate, br', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %% [markdown]
# # Params

# %%
url ='https://api.openaq.org/v2/countries'

# %%
cParams = {'code':'CO','name': 'Colombia', 'locations': 60}

# %%
Resp = rq.get(url, params=cParams)

# %%
print(Resp.json())
# Out:
# {'meta': {'name': 'openaq-api', 'license': '', 'website': '/', 'page': 1, 'limit': 100, 'found': '>100'}, 'results': [{'code': 'AF', 'name': 'Afghanistan', 'locations': 2, 'firstUpdated': '2019-10-20 22:30:00+00', 'lastUpdated': '2021-08-16 18:00:00+00', 'parameters': ['pm25'], 'count': 23640, 'cities': 1, 'sources': 2}, {'code': 'DZ', 'name': 'Algeria', 'locations': 1, 'firstUpdated': '2019-06-15 22:00:00+00', 'lastUpdated': '2024-05-31 18:00:00+00', 'parameters': ['pm25'], 'count': 38747, 'cities': 1, 'sources': 1}, {'code': 'AQ', 'name': 'Antarctica', 'locations': 2, 'firstUpdated': '2018-11-30 11:00:00+00', 'lastUpdated': '2021-02-04 14:00:00+00', 'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'], 'count': 9180, 'cities': 0, 'sources': 2}, {'code': 'AR', 'name': 'Argentina', 'locations': 17, 'firstUpdated': '2016-01-01 03:00:00+00', 'lastUpdated': '2024-05-31 18:00:00+00', 'parameters': ['co', 'no', 'no2', 'nox', 'o3', 'pm1', 'pm10', 'pm25', 'relativehumidity', 'so2', 'temperature', 'um003'], 'count': 290118, 'cities': 1, 'sources': 6}, {'code': 'AM', 'name': 'Armenia', 'locations': 1, 'firstUpdated': '2022-11-14 08:00:00+00', 'lastUpdated': '2023-06-15 11:00:00+00', 'parameters': ['pm25'], 'count': 1284, 'cities': 1, 'sources': 1}, {'code': 'AU', 'name': 'Australia', 'locations': 244, 'firstUpdated': '2016-01-28 19:00:00+00', 'lastUpdated': '2024-05-31 18:24:08+00', 'parameters': ['co', 'no2', 'o3', 'pm1', 'pm10', 'pm25', 'relativehumidity', 'so2', 'temperature', 'um003'], 'count': 13897588, 'cities': 55, 'sources': 10}, {'code': 'AT', 'name': 'Austria', 'locations': 375, 'firstUpdated': '2016-11-18 05:00:00+00', 'lastUpdated': '2024-05-31 17:00:00+00', 'parameters': ['co', 'no', 'no2', 'o3', 'pm1', 'pm10', 'pm25', 'relativehumidity', 'so2', 'temperature', 'um003'], 'count': 13439969, 'cities': 162, 'sources': 4}, {'code': 'AZ', 'name': 'Azerbaijan', 'locations': 1, 'firstUpdated': '2022-06-23 12:00:00+00', 'lastUpdated': '2024-05-31 16:00:00+00', 'parameters': ['pm25'], 'count': 12869, 'cities': 1, 'sources': 1}, {'code': 'BD', 'name': 'Bangladesh', 'locations': 4, 'firstUpdated': '2016-03-10 22:00:00+00', 'lastUpdated': '2024-05-31 17:00:00+00', 'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'], 'count': 139723, 'cities': 1, 'sources': 3}, {'code': 'BE', 'name': 'Belgium', 'locations': 174, 'firstUpdated': '2016-01-30 01:00:00+00', 'lastUpdated': '2024-05-31 17:00:00+00', 'parameters': ['co', 'no', 'no2', 'o3', 'pm1', 'pm10', 'pm25', 'relativehumidity', 'so2', 'temperature', 'um003'], 'count': 4789164, 'cities': 77, 'sources': 6}, {'code': 'BZ', 'name': 'Belize', 'locations': 1, 'firstUpdated': '2023-03-19 20:00:00+00', 'lastUpdated': '2024-05-31 17:00:00+00', 'parameters': ['pm25'], 'count': 8028, 'cities': 1, 'sources': 1}, {'code': 'BA', 'name': 'Bosnia and Herz.', 'locations': 47, 'firstUpdated': '2016-04-26 21:30:00+00', 'lastUpdated': '2024-05-31 18:00:00+00', 'parameters': ['co', 'no2', 'o3', 'pm1', 'pm10', 'pm25', 'relativehumidity', 'so2', 'temperature', 'um003'], 'count': 1360097, 'cities': 22, 'sources': 6}, {'code': 'BR', 'name': 'Brazil', 'locations': 75, 'firstUpdated': '2017-07-01 00:00:00+00', 'lastUpdated': '2024-05-31 18:00:00+00', 'parameters': ['co', 'humidity', 'no', 'no2', 'nox', 'o3', 'pm1', 'pm10', 'pm25', 'pressure', 'so2', 'temperature', 'um003', 'um005', 'um010', 'um025', 'um050', 'um100', 'voc'], 'count': 3057628, 'cities': 39, 'sources': 5}, {'code': 'BG', 'name': 'Bulgaria', 'locations': 105, 'firstUpdated': '2020-04-20 18:00:00+00', 'lastUpdated': '2024-05-31 18:44:00+00', 'parameters': ['co', 'humidity', 'no', 'no2', 'o3', 'pm1', 'pm10', 'pm25', 'pm4', 'pressure', 'so2', 'temperature'], 'count': 127889965, 'cities': 2, 'sources': 2}, {'code': 'CA', 'name': 'Canada', 'locations': 366, 'firstUpdated': '2016-03-06 19:00:00+00', 'lastUpdated': '2024-05-31 18:06:18.647+00', 'parameters': ['co', 'no', 'no2', 'nox', 'o3', 'pm1', 'pm10', 'pm25', 'relativehumidity', 'so2', 'temperatu ...

# %%
rResp.json()
# Out:
# {'meta': {'name': 'openaq-api',
#   'license': '',
#   'website': '/',
#   'page': 1,
#   'limit': 100,
#   'found': '>100'},
#  'results': [{'code': 'AF',
#    'name': 'Afghanistan',
#    'locations': 2,
#    'firstUpdated': '2019-10-20 22:30:00+00',
#    'lastUpdated': '2021-08-16 18:00:00+00',
#    'parameters': ['pm25'],
#    'count': 23640,
#    'cities': 1,
#    'sources': 2},
#   {'code': 'DZ',
#    'name': 'Algeria',
#    'locations': 1,
#    'firstUpdated': '2019-06-15 22:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['pm25'],
#    'count': 38747,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'AQ',
#    'name': 'Antarctica',
#    'locations': 2,
#    'firstUpdated': '2018-11-30 11:00:00+00',
#    'lastUpdated': '2021-02-04 14:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 9180,
#    'cities': 0,
#    'sources': 2},
#   {'code': 'AR',
#    'name': 'Argentina',
#    'locations': 17,
#    'firstUpdated': '2016-01-01 03:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'nox',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 290118,
#    'cities': 1,
#    'sources': 6},
#   {'code': 'AM',
#    'name': 'Armenia',
#    'locations': 1,
#    'firstUpdated': '2022-11-14 08:00:00+00',
#    'lastUpdated': '2023-06-15 11:00:00+00',
#    'parameters': ['pm25'],
#    'count': 1284,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'AU',
#    'name': 'Australia',
#    'locations': 244,
#    'firstUpdated': '2016-01-28 19:00:00+00',
#    'lastUpdated': '2024-05-31 18:24:08+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 13897588,
#    'cities': 55,
#    'sources': 10},
#   {'code': 'AT',
#    'name': 'Austria',
#    'locations': 375,
#    'firstUpdated': '2016-11-18 05:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 13439969,
#    'cities': 162,
#    'sources': 4},
#   {'code': 'AZ',
#    'name': 'Azerbaijan',
#    'locations': 1,
#    'firstUpdated': '2022-06-23 12:00:00+00',
#    'lastUpdated': '2024-05-31 16:00:00+00',
#    'parameters': ['pm25'],
#    'count': 12869,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'BD',
#    'name': 'Bangladesh',
#    'locations': 4,
#    'firstUpdated': '2016-03-10 22:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 139723,
#    'cities': 1,
#    'sources': 3},
#   {'code': 'BE',
#    'name': 'Belgium',
#    'locations': 174,
#    'firstUpdated': '2016-01-30 01:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 4789164,
#    'cities': 77,
#    'sources': 6},
#   {'code': 'BZ',
#    'name': 'Belize',
#    'locations': 1,
#    'firstUpdated': '2023-03-19 20:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['pm25'],
#    'count': 8028,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'BA',
#    'name': 'Bosnia and Herz.',
#    'locations': 47,
#    'firstUpdated': '2016-04-26 21:30:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 1360097,
#    'cities': 22,
#    'sources': 6},
#   {'code': 'BR',
#    'name': 'Brazil',
#    'locations': 75,
#    'firstUpdated': '2017-07-01 00:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co',
#     'humidity',
#     'no',
#     'no2',
#     'nox',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'pressure',
#     'so2',
#     'temperature',
#     'um003',
#     'um005',
#     'um010',
#     'um025',
#     'um050',
#     'um100',
#     'voc'],
#    'count': 3057628,
#    'cities': 39,
#    'sources': 5},
#   {'code': 'BG',
#    'name': 'Bulgaria',
#    'locations': 105,
#    'firstUpdated': '2020-04-20 18:00:00+00',
#    'lastUpdated': '2024-05-31 18:44:00+00',
#    'parameters': ['co',
#     'humidity',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'pm4',
#     'pressure',
#     'so2',
#     'temperature'],
#    'count': 127889965,
#    'cities': 2,
#    'sources': 2},
#   {'code': 'CA',
#    'name': 'Canada',
#    'locations': 366,
#    'firstUpdated': '2016-03-06 19:00:00+00',
#    'lastUpdated': '2024-05-31 18:06:18.647+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'nox',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 18394401,
#    'cities': 18,
#    'sources': 5},
#   {'code': 'TD',
#    'name': 'Chad',
#    'locations': 1,
#    'firstUpdated': '2020-08-02 20:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['pm25'],
#    'count': 29073,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'CL',
#    'name': 'Chile',
#    'locations': 154,
#    'firstUpdated': '2016-01-30 01:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 10847919,
#    'cities': 61,
#    'sources': 2},
#   {'code': 'CN',
#    'name': 'China',
#    'locations': 1873,
#    'firstUpdated': '2016-01-01 01:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 170596157,
#    'cities': 18,
#    'sources': 19},
#   {'code': 'CO',
#    'name': 'Colombia',
#    'locations': 60,
#    'firstUpdated': '2016-03-17 15:00:00+00',
#    'lastUpdated': '2024-05-31 18:05:11.963+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 2419898,
#    'cities': 10,
#    'sources': 5},
#   {'code': 'CR',
#    'name': 'Costa Rica',
#    'locations': 1,
#    'firstUpdated': '2019-10-28 18:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['pm25'],
#    'count': 33197,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'CI',
#    'name': "Côte d'Ivoire",
#    'locations': 1,
#    'firstUpdated': '2020-03-15 21:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['pm25'],
#    'count': 29814,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'HR',
#    'name': 'Croatia',
#    'locations': 27,
#    'firstUpdated': '2016-11-17 22:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 1505384,
#    'cities': 16,
#    'sources': 3},
#   {'code': 'CY',
#    'name': 'Cyprus',
#    'locations': 11,
#    'firstUpdated': '2020-04-20 16:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co', 'no', 'no2', 'nox', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 654077,
#    'cities': 11,
#    'sources': 2},
#   {'code': 'CZ',
#    'name': 'Czechia',
#    'locations': 124,
#    'firstUpdated': '2016-11-21 11:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 11850910,
#    'cities': 72,
#    'sources': 4},
#   {'code': 'CD',
#    'name': 'Dem. Rep. Congo',
#    'locations': 1,
#    'firstUpdated': '2022-06-16 16:00:00+00',
#    'lastUpdated': '2024-05-31 10:00:00+00',
#    'parameters': ['pm25'],
#    'count': 3812,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'DK',
#    'name': 'Denmark',
#    'locations': 15,
#    'firstUpdated': '2016-11-21 11:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm10',
#     'pm25',
#     'so2',
#     'temperature'],
#    'count': 1046875,
#    'cities': 9,
#    'sources': 3},
#   {'code': 'EC',
#    'name': 'Ecuador',
#    'locations': 10,
#    'firstUpdated': '2020-12-29 05:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 94237,
#    'cities': 0,
#    'sources': 2},
#   {'code': 'EG',
#    'name': 'Egypt',
#    'locations': 2,
#    'firstUpdated': '2022-06-20 18:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['pm25'],
#    'count': 10944,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'EE',
#    'name': 'Estonia',
#    'locations': 7,
#    'firstUpdated': '2020-04-20 20:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 259008,
#    'cities': 5,
#    'sources': 1},
#   {'code': 'ET',
#    'name': 'Ethiopia',
#    'locations': 3,
#    'firstUpdated': '2016-08-18 22:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['pm25'],
#    'count': 113926,
#    'cities': 2,
#    'sources': 2},
#   {'code': 'FI',
#    'name': 'Finland',
#    'locations': 81,
#    'firstUpdated': '2016-12-10 19:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 4450330,
#    'cities': 32,
#    'sources': 2},
#   {'code': 'FR',
#    'name': 'France',
#    'locations': 793,
#    'firstUpdated': '2016-11-17 23:00:00+00',
#    'lastUpdated': '2024-05-31 18:02:01.284+00',
#    'parameters': ['co',
#     'humidity',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'pressure',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003',
#     'um005',
#     'um010',
#     'um025',
#     'um050',
#     'um100'],
#    'count': 46357815,
#    'cities': 418,
#    'sources': 8},
#   {'code': 'GA',
#    'name': 'Gabon',
#    'locations': 1,
#    'firstUpdated': '2021-10-06 12:00:00+00',
#    'lastUpdated': '2022-02-27 19:00:00+00',
#    'parameters': ['pm25'],
#    'count': 2828,
#    'cities': 0,
#    'sources': 1},
#   {'code': 'GM',
#    'name': 'Gambia',
#    'locations': 1,
#    'firstUpdated': '2022-10-20 01:00:00+00',
#    'lastUpdated': '2023-09-15 23:03:55.489+00',
#    'parameters': ['no2', 'pm1', 'pm10', 'pm25'],
#    'count': 12354,
#    'cities': 0,
#    'sources': 1},
#   {'code': 'DE',
#    'name': 'Germany',
#    'locations': 514,
#    'firstUpdated': '2016-01-30 01:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 24141437,
#    'cities': 291,
#    'sources': 4},
#   {'code': 'GH',
#    'name': 'Ghana',
#    'locations': 12,
#    'firstUpdated': '2020-05-01 01:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['no2',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 1170945,
#    'cities': 1,
#    'sources': 3},
#   {'code': 'GR',
#    'name': 'Greece',
#    'locations': 52,
#    'firstUpdated': '2020-04-20 18:00:00+00',
#    'lastUpdated': '2024-05-31 18:44:00+00',
#    'parameters': ['co',
#     'humidity',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'pm4',
#     'pressure',
#     'so2',
#     'temperature'],
#    'count': 7458599,
#    'cities': 8,
#    'sources': 3},
#   {'code': 'GT',
#    'name': 'Guatemala',
#    'locations': 2,
#    'firstUpdated': '2019-10-20 21:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['o3', 'pm10', 'pm25'],
#    'count': 96351,
#    'cities': 2,
#    'sources': 2},
#   {'code': 'GN',
#    'name': 'Guinea',
#    'locations': 1,
#    'firstUpdated': '2020-05-01 02:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['pm25'],
#    'count': 28481,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'HU',
#    'name': 'Hungary',
#    'locations': 97,
#    'firstUpdated': '2016-12-12 14:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 5717102,
#    'cities': 64,
#    'sources': 3},
#   {'code': 'IS',
#    'name': 'Iceland',
#    'locations': 24,
#    'firstUpdated': '2020-02-28 01:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 829455,
#    'cities': 8,
#    'sources': 3},
#   {'code': 'IN',
#    'name': 'India',
#    'locations': 421,
#    'firstUpdated': '2016-01-30 00:30:00+00',
#    'lastUpdated': '2024-05-31 17:30:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 42138688,
#    'cities': 3,
#    'sources': 10},
#   {'code': 'ID',
#    'name': 'Indonesia',
#    'locations': 12,
#    'firstUpdated': '2016-01-30 01:00:00+00',
#    'lastUpdated': '2024-05-31 18:04:49.524+00',
#    'parameters': ['o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 140133,
#    'cities': 2,
#    'sources': 7},
#   {'code': 'IQ',
#    'name': 'Iraq',
#    'locations': 5,
#    'firstUpdated': '2019-03-10 16:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 71317,
#    'cities': 3,
#    'sources': 3},
#   {'code': 'IE',
#    'name': 'Ireland',
#    'locations': 45,
#    'firstUpdated': '2016-02-27 21:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 1696777,
#    'cities': 5,
#    'sources': 4},
#   {'code': 'IL',
#    'name': 'Israel',
#    'locations': 111,
#    'firstUpdated': '2016-01-01 01:00:00+00',
#    'lastUpdated': '2021-11-19 09:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm25', 'so2'],
#    'count': 19575369,
#    'cities': 1,
#    'sources': 2},
#   {'code': 'IT',
#    'name': 'Italy',
#    'locations': 746,
#    'firstUpdated': '2016-11-21 12:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'nox',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 25631256,
#    'cities': 600,
#    'sources': 8},
#   {'code': 'JP',
#    'name': 'Japan',
#    'locations': 1539,
#    'firstUpdated': '2023-07-14 17:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co', 'no', 'no2', 'nox', 'pm25', 'so2', 'temperature'],
#    'count': 38208605,
#    'cities': 1,
#    'sources': 3},
#   {'code': 'JO',
#    'name': 'Jordan',
#    'locations': 5,
#    'firstUpdated': '2017-08-10 23:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm25', 'so2'],
#    'count': 648902,
#    'cities': 2,
#    'sources': 3},
#   {'code': 'KZ',
#    'name': 'Kazakhstan',
#    'locations': 40,
#    'firstUpdated': '2018-07-27 16:00:00+00',
#    'lastUpdated': '2024-05-31 18:06:42.055+00',
#    'parameters': ['pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 149306,
#    'cities': 1,
#    'sources': 3},
#   {'code': 'KE',
#    'name': 'Kenya',
#    'locations': 6,
#    'firstUpdated': '2018-04-21 00:00:00+00',
#    'lastUpdated': '2024-05-31 18:01:10.061+00',
#    'parameters': ['pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 21490,
#    'cities': 1,
#    'sources': 4},
#   {'code': 'XK',
#    'name': 'Kosovo',
#    'locations': 24,
#    'firstUpdated': '2016-04-08 20:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 612958,
#    'cities': 12,
#    'sources': 4},
#   {'code': 'KW',
#    'name': 'Kuwait',
#    'locations': 1,
#    'firstUpdated': '2017-02-17 21:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['pm25'],
#    'count': 54958,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'KG',
#    'name': 'Kyrgyzstan',
#    'locations': 47,
#    'firstUpdated': '2019-03-08 20:00:00+00',
#    'lastUpdated': '2024-05-31 18:06:33.546+00',
#    'parameters': ['pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 188493,
#    'cities': 2,
#    'sources': 4},
#   {'code': 'LA',
#    'name': 'Laos',
#    'locations': 9,
#    'firstUpdated': '2021-04-29 19:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 227986,
#    'cities': 4,
#    'sources': 3},
#   {'code': 'LV',
#    'name': 'Latvia',
#    'locations': 13,
#    'firstUpdated': '2017-09-22 10:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 430248,
#    'cities': 5,
#    'sources': 2},
#   {'code': 'LT',
#    'name': 'Lithuania',
#    'locations': 17,
#    'firstUpdated': '2017-09-21 23:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 924030,
#    'cities': 13,
#    'sources': 2},
#   {'code': 'LU',
#    'name': 'Luxembourg',
#    'locations': 12,
#    'firstUpdated': '2017-09-22 10:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co', 'no', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 870723,
#    'cities': 1,
#    'sources': 2},
#   {'code': 'MK',
#    'name': 'Macedonia',
#    'locations': 28,
#    'firstUpdated': '2016-12-10 20:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co', 'no', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 2972749,
#    'cities': 6,
#    'sources': 2},
#   {'code': 'MG',
#    'name': 'Madagascar',
#    'locations': 1,
#    'firstUpdated': '2020-12-22 06:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['pm25'],
#    'count': 21959,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'MY',
#    'name': 'Malaysia',
#    'locations': 11,
#    'firstUpdated': '2016-04-05 09:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 115827,
#    'cities': 4,
#    'sources': 4},
#   {'code': 'ML',
#    'name': 'Mali',
#    'locations': 1,
#    'firstUpdated': '2020-03-16 05:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['pm25'],
#    'count': 25555,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'MX',
#    'name': 'Mexico',
#    'locations': 237,
#    'firstUpdated': '2016-03-06 19:00:00+00',
#    'lastUpdated': '2024-05-31 19:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'nox',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 10851220,
#    'cities': 111,
#    'sources': 4},
#   {'code': 'MD',
#    'name': 'Moldova',
#    'locations': 2,
#    'firstUpdated': '2020-04-20 19:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['no2', 'pm10', 'pm25', 'so2'],
#    'count': 35574,
#    'cities': 2,
#    'sources': 2},
#   {'code': 'MN',
#    'name': 'Mongolia',
#    'locations': 44,
#    'firstUpdated': '2016-01-30 00:15:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 2359003,
#    'cities': 23,
#    'sources': 4},
#   {'code': 'ME',
#    'name': 'Montenegro',
#    'locations': 9,
#    'firstUpdated': '2022-03-24 14:00:00+00',
#    'lastUpdated': '2024-03-19 22:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 273080,
#    'cities': 7,
#    'sources': 1},
#   {'code': 'MA',
#    'name': 'Morocco',
#    'locations': 2,
#    'firstUpdated': '2024-04-04 10:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 8904,
#    'cities': 0,
#    'sources': 1},
#   {'code': 'MZ',
#    'name': 'Mozambique',
#    'locations': 1,
#    'firstUpdated': '2024-01-18 18:00:00+00',
#    'lastUpdated': '2024-01-22 16:00:00+00',
#    'parameters': ['o3', 'pm25'],
#    'count': 137,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'MM',
#    'name': 'Myanmar',
#    'locations': 5,
#    'firstUpdated': '2016-01-30 01:00:00+00',
#    'lastUpdated': '2024-05-31 17:30:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 320480,
#    'cities': 3,
#    'sources': 4},
#   {'code': 'NP',
#    'name': 'Nepal',
#    'locations': 4,
#    'firstUpdated': '2017-03-02 23:15:00+00',
#    'lastUpdated': '2024-05-31 17:15:00+00',
#    'parameters': ['o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 222873,
#    'cities': 2,
#    'sources': 3},
#   {'code': 'NL',
#    'name': 'Netherlands',
#    'locations': 98,
#    'firstUpdated': '2016-01-30 01:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 13101369,
#    'cities': 50,
#    'sources': 4},
#   {'code': 'NZ',
#    'name': 'New Zealand',
#    'locations': 12,
#    'firstUpdated': '2023-03-31 15:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 99171,
#    'cities': 8,
#    'sources': 2},
#   {'code': 'NG',
#    'name': 'Nigeria',
#    'locations': 5,
#    'firstUpdated': '2019-04-26 08:00:00+00',
#    'lastUpdated': '2024-05-31 18:05:12.654+00',
#    'parameters': ['pm25'],
#    'count': 23730,
#    'cities': 2,
#    'sources': 3},
#   {'code': 'KP',
#    'name': 'North Korea',
#    'locations': 4,
#    'firstUpdated': '2024-03-20 08:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 30243,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'NO',
#    'name': 'Norway',
#    'locations': 354,
#    'firstUpdated': '2016-12-02 10:00:00+00',
#    'lastUpdated': '2024-05-31 18:44:00+00',
#    'parameters': ['bc',
#     'co',
#     'co2',
#     'humidity',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'pm4',
#     'pressure',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003',
#     'um005',
#     'um010',
#     'um025',
#     'um050',
#     'um100'],
#    'count': 36187746,
#    'cities': 27,
#    'sources': 5},
#   {'code': 'PK',
#    'name': 'Pakistan',
#    'locations': 6,
#    'firstUpdated': '2019-05-22 22:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['pm25'],
#    'count': 168687,
#    'cities': 4,
#    'sources': 5},
#   {'code': 'PS',
#    'name': 'Palestine',
#    'locations': 9,
#    'firstUpdated': '2017-08-10 23:00:00+00',
#    'lastUpdated': '2019-04-03 21:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'so2'],
#    'count': 1449100,
#    'cities': 0,
#    'sources': 1},
#   {'code': 'PY',
#    'name': 'Paraguay',
#    'locations': 1,
#    'firstUpdated': '2023-10-02 19:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['pm25'],
#    'count': 5128,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'PE',
#    'name': 'Peru',
#    'locations': 46,
#    'firstUpdated': '2016-03-04 17:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 2363656,
#    'cities': 21,
#    'sources': 5},
#   {'code': 'PH',
#    'name': 'Philippines',
#    'locations': 5,
#    'firstUpdated': '2023-09-06 20:00:00+00',
#    'lastUpdated': '2024-05-31 18:02:44.129+00',
#    'parameters': ['pm25', 'temperature'],
#    'count': 12900,
#    'cities': 1,
#    'sources': 3},
#   {'code': 'PL',
#    'name': 'Poland',
#    'locations': 331,
#    'firstUpdated': '2016-01-30 01:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['bc',
#     'co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 25858549,
#    'cities': 197,
#    'sources': 5},
#   {'code': 'PT',
#    'name': 'Portugal',
#    'locations': 70,
#    'firstUpdated': '2017-05-11 08:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 6864465,
#    'cities': 8,
#    'sources': 3},
#   {'code': 'PR',
#    'name': 'Puerto Rico',
#    'locations': 5,
#    'firstUpdated': '2016-05-04 11:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['o3', 'pm10', 'pm25'],
#    'count': 99760,
#    'cities': 2,
#    'sources': 1},
#   {'code': 'QA',
#    'name': 'Qatar',
#    'locations': 1,
#    'firstUpdated': '2022-04-11 14:00:00+00',
#    'lastUpdated': '2023-11-30 08:00:00+00',
#    'parameters': ['o3', 'pm25'],
#    'count': 16513,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'RO',
#    'name': 'Romania',
#    'locations': 318,
#    'firstUpdated': '2020-04-19 21:00:00+00',
#    'lastUpdated': '2024-05-31 18:06:38.617+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 5275200,
#    'cities': 109,
#    'sources': 4},
#   {'code': 'RU',
#    'name': 'Russia',
#    'locations': 54,
#    'firstUpdated': '2016-11-21 11:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 561138,
#    'cities': 2,
#    'sources': 5},
#   {'code': 'RW',
#    'name': 'Rwanda',
#    'locations': 2,
#    'firstUpdated': '2020-12-28 22:45:00+00',
#    'lastUpdated': '2024-05-14 00:00:00+00',
#    'parameters': ['co', 'no2', 'pm10', 'pm25'],
#    'count': 126004,
#    'cities': 1,
#    'sources': 2},
#   {'code': 'SA',
#    'name': 'Saudi Arabia',
#    'locations': 5,
#    'firstUpdated': '2019-07-15 19:00:00+00',
#    'lastUpdated': '2024-05-31 00:00:00+00',
#    'parameters': ['co', 'no2', 'pm10', 'pm25', 'so2'],
#    'count': 21342,
#    'cities': 3,
#    'sources': 3},
#   {'code': 'SN',
#    'name': 'Senegal',
#    'locations': 1,
#    'firstUpdated': '2023-09-05 08:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 7574,
#    'cities': 0,
#    'sources': 1},
#   {'code': 'RS',
#    'name': 'Serbia',
#    'locations': 85,
#    'firstUpdated': '2017-09-22 09:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2', 'temperature'],
#    'count': 3327150,
#    'cities': 44,
#    'sources': 5},
#   {'code': 'SK',
#    'name': 'Slovakia',
#    'locations': 85,
#    'firstUpdated': '2016-11-18 05:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co', 'no', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 5938390,
#    'cities': 58,
#    'sources': 3},
#   {'code': 'SI',
#    'name': 'Slovenia',
#    'locations': 39,
#    'firstUpdated': '2016-11-17 22:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 793207,
#    'cities': 26,
#    'sources': 3},
#   {'code': 'ZA',
#    'name': 'South Africa',
#    'locations': 200,
#    'firstUpdated': '2016-02-14 08:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'nox',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 4691551,
#    'cities': 36,
#    'sources': 4},
#   {'code': 'KR',
#    'name': 'South Korea',
#    'locations': 686,
#    'firstUpdated': '2020-10-12 06:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 6431385,
#    'cities': 3,
#    'sources': 3},
#   {'code': 'ES',
#    'name': 'Spain',
#    'locations': 738,
#    'firstUpdated': '2016-11-17 23:00:00+00',
#    'lastUpdated': '2024-05-31 18:44:00+00',
#    'parameters': ['co',
#     'humidity',
#     'no',
#     'no2',
#     'nox',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'pm4',
#     'pressure',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 45040033,
#    'cities': 352,
#    'sources': 7},
#   {'code': 'LK',
#    'name': 'Sri Lanka',
#    'locations': 1,
#    'firstUpdated': '2019-06-25 21:30:00+00',
#    'lastUpdated': '2024-05-30 18:30:00+00',
#    'parameters': ['pm25'],
#    'count': 21875,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'SD',
#    'name': 'Sudan',
#    'locations': 3,
#    'firstUpdated': '2020-05-14 14:00:00+00',
#    'lastUpdated': '2023-05-17 13:00:00+00',
#    'parameters': ['pm25'],
#    'count': 54546,
#    'cities': 2,
#    'sources': 3},
#   {'code': 'SE',
#    'name': 'Sweden',
#    'locations': 170,
#    'firstUpdated': '2016-12-02 11:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co', 'no', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 2549561,
#    'cities': 53,
#    'sources': 5},
#   {'code': 'CH',
#    'name': 'Switzerland',
#    'locations': 51,
#    'firstUpdated': '2016-11-21 12:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 3298540,
#    'cities': 13,
#    'sources': 3},
#   {'code': 'TW',
#    'name': 'Taiwan',
#    'locations': 91,
#    'firstUpdated': '2016-12-20 19:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 8405956,
#    'cities': 17,
#    'sources': 2}]}

# %% [markdown]
# # Authentication

# %%
url = 'https://api.openaq.org/v2/countries'

# %%
aAuth = ("name","Afghanistan")

type(aAuth)
# Out:
# tuple

# %%
authResp = rq.get(url, auth=aAuth)
authResp
# Out:
# <Response [200]>

# %%
authResp.json()
# Out:
# {'meta': {'name': 'openaq-api',
#   'license': '',
#   'website': '/',
#   'page': 1,
#   'limit': 100,
#   'found': '>100'},
#  'results': [{'code': 'AF',
#    'name': 'Afghanistan',
#    'locations': 2,
#    'firstUpdated': '2019-10-20 22:30:00+00',
#    'lastUpdated': '2021-08-16 18:00:00+00',
#    'parameters': ['pm25'],
#    'count': 23640,
#    'cities': 1,
#    'sources': 2},
#   {'code': 'DZ',
#    'name': 'Algeria',
#    'locations': 1,
#    'firstUpdated': '2019-06-15 22:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['pm25'],
#    'count': 38747,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'AQ',
#    'name': 'Antarctica',
#    'locations': 2,
#    'firstUpdated': '2018-11-30 11:00:00+00',
#    'lastUpdated': '2021-02-04 14:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 9180,
#    'cities': 0,
#    'sources': 2},
#   {'code': 'AR',
#    'name': 'Argentina',
#    'locations': 17,
#    'firstUpdated': '2016-01-01 03:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'nox',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 290118,
#    'cities': 1,
#    'sources': 6},
#   {'code': 'AM',
#    'name': 'Armenia',
#    'locations': 1,
#    'firstUpdated': '2022-11-14 08:00:00+00',
#    'lastUpdated': '2023-06-15 11:00:00+00',
#    'parameters': ['pm25'],
#    'count': 1284,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'AU',
#    'name': 'Australia',
#    'locations': 244,
#    'firstUpdated': '2016-01-28 19:00:00+00',
#    'lastUpdated': '2024-05-31 18:24:08+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 13897588,
#    'cities': 55,
#    'sources': 10},
#   {'code': 'AT',
#    'name': 'Austria',
#    'locations': 375,
#    'firstUpdated': '2016-11-18 05:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 13439969,
#    'cities': 162,
#    'sources': 4},
#   {'code': 'AZ',
#    'name': 'Azerbaijan',
#    'locations': 1,
#    'firstUpdated': '2022-06-23 12:00:00+00',
#    'lastUpdated': '2024-05-31 16:00:00+00',
#    'parameters': ['pm25'],
#    'count': 12869,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'BD',
#    'name': 'Bangladesh',
#    'locations': 4,
#    'firstUpdated': '2016-03-10 22:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 139723,
#    'cities': 1,
#    'sources': 3},
#   {'code': 'BE',
#    'name': 'Belgium',
#    'locations': 174,
#    'firstUpdated': '2016-01-30 01:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 4789164,
#    'cities': 77,
#    'sources': 6},
#   {'code': 'BZ',
#    'name': 'Belize',
#    'locations': 1,
#    'firstUpdated': '2023-03-19 20:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['pm25'],
#    'count': 8028,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'BA',
#    'name': 'Bosnia and Herz.',
#    'locations': 47,
#    'firstUpdated': '2016-04-26 21:30:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 1360097,
#    'cities': 22,
#    'sources': 6},
#   {'code': 'BR',
#    'name': 'Brazil',
#    'locations': 75,
#    'firstUpdated': '2017-07-01 00:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co',
#     'humidity',
#     'no',
#     'no2',
#     'nox',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'pressure',
#     'so2',
#     'temperature',
#     'um003',
#     'um005',
#     'um010',
#     'um025',
#     'um050',
#     'um100',
#     'voc'],
#    'count': 3057628,
#    'cities': 39,
#    'sources': 5},
#   {'code': 'BG',
#    'name': 'Bulgaria',
#    'locations': 105,
#    'firstUpdated': '2020-04-20 18:00:00+00',
#    'lastUpdated': '2024-05-31 18:44:00+00',
#    'parameters': ['co',
#     'humidity',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'pm4',
#     'pressure',
#     'so2',
#     'temperature'],
#    'count': 127889965,
#    'cities': 2,
#    'sources': 2},
#   {'code': 'CA',
#    'name': 'Canada',
#    'locations': 366,
#    'firstUpdated': '2016-03-06 19:00:00+00',
#    'lastUpdated': '2024-05-31 18:06:18.647+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'nox',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 18394401,
#    'cities': 18,
#    'sources': 5},
#   {'code': 'TD',
#    'name': 'Chad',
#    'locations': 1,
#    'firstUpdated': '2020-08-02 20:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['pm25'],
#    'count': 29073,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'CL',
#    'name': 'Chile',
#    'locations': 154,
#    'firstUpdated': '2016-01-30 01:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 10847919,
#    'cities': 61,
#    'sources': 2},
#   {'code': 'CN',
#    'name': 'China',
#    'locations': 1873,
#    'firstUpdated': '2016-01-01 01:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 170596157,
#    'cities': 18,
#    'sources': 19},
#   {'code': 'CO',
#    'name': 'Colombia',
#    'locations': 60,
#    'firstUpdated': '2016-03-17 15:00:00+00',
#    'lastUpdated': '2024-05-31 18:05:11.963+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 2419898,
#    'cities': 10,
#    'sources': 5},
#   {'code': 'CR',
#    'name': 'Costa Rica',
#    'locations': 1,
#    'firstUpdated': '2019-10-28 18:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['pm25'],
#    'count': 33197,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'CI',
#    'name': "Côte d'Ivoire",
#    'locations': 1,
#    'firstUpdated': '2020-03-15 21:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['pm25'],
#    'count': 29814,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'HR',
#    'name': 'Croatia',
#    'locations': 27,
#    'firstUpdated': '2016-11-17 22:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 1505384,
#    'cities': 16,
#    'sources': 3},
#   {'code': 'CY',
#    'name': 'Cyprus',
#    'locations': 11,
#    'firstUpdated': '2020-04-20 16:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co', 'no', 'no2', 'nox', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 654077,
#    'cities': 11,
#    'sources': 2},
#   {'code': 'CZ',
#    'name': 'Czechia',
#    'locations': 124,
#    'firstUpdated': '2016-11-21 11:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 11850910,
#    'cities': 72,
#    'sources': 4},
#   {'code': 'CD',
#    'name': 'Dem. Rep. Congo',
#    'locations': 1,
#    'firstUpdated': '2022-06-16 16:00:00+00',
#    'lastUpdated': '2024-05-31 10:00:00+00',
#    'parameters': ['pm25'],
#    'count': 3812,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'DK',
#    'name': 'Denmark',
#    'locations': 15,
#    'firstUpdated': '2016-11-21 11:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm10',
#     'pm25',
#     'so2',
#     'temperature'],
#    'count': 1046875,
#    'cities': 9,
#    'sources': 3},
#   {'code': 'EC',
#    'name': 'Ecuador',
#    'locations': 10,
#    'firstUpdated': '2020-12-29 05:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 94237,
#    'cities': 0,
#    'sources': 2},
#   {'code': 'EG',
#    'name': 'Egypt',
#    'locations': 2,
#    'firstUpdated': '2022-06-20 18:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['pm25'],
#    'count': 10944,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'EE',
#    'name': 'Estonia',
#    'locations': 7,
#    'firstUpdated': '2020-04-20 20:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 259008,
#    'cities': 5,
#    'sources': 1},
#   {'code': 'ET',
#    'name': 'Ethiopia',
#    'locations': 3,
#    'firstUpdated': '2016-08-18 22:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['pm25'],
#    'count': 113926,
#    'cities': 2,
#    'sources': 2},
#   {'code': 'FI',
#    'name': 'Finland',
#    'locations': 81,
#    'firstUpdated': '2016-12-10 19:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 4450330,
#    'cities': 32,
#    'sources': 2},
#   {'code': 'FR',
#    'name': 'France',
#    'locations': 793,
#    'firstUpdated': '2016-11-17 23:00:00+00',
#    'lastUpdated': '2024-05-31 18:02:01.284+00',
#    'parameters': ['co',
#     'humidity',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'pressure',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003',
#     'um005',
#     'um010',
#     'um025',
#     'um050',
#     'um100'],
#    'count': 46357815,
#    'cities': 418,
#    'sources': 8},
#   {'code': 'GA',
#    'name': 'Gabon',
#    'locations': 1,
#    'firstUpdated': '2021-10-06 12:00:00+00',
#    'lastUpdated': '2022-02-27 19:00:00+00',
#    'parameters': ['pm25'],
#    'count': 2828,
#    'cities': 0,
#    'sources': 1},
#   {'code': 'GM',
#    'name': 'Gambia',
#    'locations': 1,
#    'firstUpdated': '2022-10-20 01:00:00+00',
#    'lastUpdated': '2023-09-15 23:03:55.489+00',
#    'parameters': ['no2', 'pm1', 'pm10', 'pm25'],
#    'count': 12354,
#    'cities': 0,
#    'sources': 1},
#   {'code': 'DE',
#    'name': 'Germany',
#    'locations': 514,
#    'firstUpdated': '2016-01-30 01:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 24141437,
#    'cities': 291,
#    'sources': 4},
#   {'code': 'GH',
#    'name': 'Ghana',
#    'locations': 12,
#    'firstUpdated': '2020-05-01 01:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['no2',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 1170945,
#    'cities': 1,
#    'sources': 3},
#   {'code': 'GR',
#    'name': 'Greece',
#    'locations': 52,
#    'firstUpdated': '2020-04-20 18:00:00+00',
#    'lastUpdated': '2024-05-31 18:44:00+00',
#    'parameters': ['co',
#     'humidity',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'pm4',
#     'pressure',
#     'so2',
#     'temperature'],
#    'count': 7458599,
#    'cities': 8,
#    'sources': 3},
#   {'code': 'GT',
#    'name': 'Guatemala',
#    'locations': 2,
#    'firstUpdated': '2019-10-20 21:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['o3', 'pm10', 'pm25'],
#    'count': 96351,
#    'cities': 2,
#    'sources': 2},
#   {'code': 'GN',
#    'name': 'Guinea',
#    'locations': 1,
#    'firstUpdated': '2020-05-01 02:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['pm25'],
#    'count': 28481,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'HU',
#    'name': 'Hungary',
#    'locations': 97,
#    'firstUpdated': '2016-12-12 14:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 5717102,
#    'cities': 64,
#    'sources': 3},
#   {'code': 'IS',
#    'name': 'Iceland',
#    'locations': 24,
#    'firstUpdated': '2020-02-28 01:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 829455,
#    'cities': 8,
#    'sources': 3},
#   {'code': 'IN',
#    'name': 'India',
#    'locations': 421,
#    'firstUpdated': '2016-01-30 00:30:00+00',
#    'lastUpdated': '2024-05-31 17:30:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 42138688,
#    'cities': 3,
#    'sources': 10},
#   {'code': 'ID',
#    'name': 'Indonesia',
#    'locations': 12,
#    'firstUpdated': '2016-01-30 01:00:00+00',
#    'lastUpdated': '2024-05-31 18:04:49.524+00',
#    'parameters': ['o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 140133,
#    'cities': 2,
#    'sources': 7},
#   {'code': 'IQ',
#    'name': 'Iraq',
#    'locations': 5,
#    'firstUpdated': '2019-03-10 16:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 71317,
#    'cities': 3,
#    'sources': 3},
#   {'code': 'IE',
#    'name': 'Ireland',
#    'locations': 45,
#    'firstUpdated': '2016-02-27 21:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 1696777,
#    'cities': 5,
#    'sources': 4},
#   {'code': 'IL',
#    'name': 'Israel',
#    'locations': 111,
#    'firstUpdated': '2016-01-01 01:00:00+00',
#    'lastUpdated': '2021-11-19 09:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm25', 'so2'],
#    'count': 19575369,
#    'cities': 1,
#    'sources': 2},
#   {'code': 'IT',
#    'name': 'Italy',
#    'locations': 746,
#    'firstUpdated': '2016-11-21 12:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'nox',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 25631256,
#    'cities': 600,
#    'sources': 8},
#   {'code': 'JP',
#    'name': 'Japan',
#    'locations': 1539,
#    'firstUpdated': '2023-07-14 17:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co', 'no', 'no2', 'nox', 'pm25', 'so2', 'temperature'],
#    'count': 38208605,
#    'cities': 1,
#    'sources': 3},
#   {'code': 'JO',
#    'name': 'Jordan',
#    'locations': 5,
#    'firstUpdated': '2017-08-10 23:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm25', 'so2'],
#    'count': 648902,
#    'cities': 2,
#    'sources': 3},
#   {'code': 'KZ',
#    'name': 'Kazakhstan',
#    'locations': 40,
#    'firstUpdated': '2018-07-27 16:00:00+00',
#    'lastUpdated': '2024-05-31 18:06:42.055+00',
#    'parameters': ['pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 149306,
#    'cities': 1,
#    'sources': 3},
#   {'code': 'KE',
#    'name': 'Kenya',
#    'locations': 6,
#    'firstUpdated': '2018-04-21 00:00:00+00',
#    'lastUpdated': '2024-05-31 18:01:10.061+00',
#    'parameters': ['pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 21490,
#    'cities': 1,
#    'sources': 4},
#   {'code': 'XK',
#    'name': 'Kosovo',
#    'locations': 24,
#    'firstUpdated': '2016-04-08 20:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 612958,
#    'cities': 12,
#    'sources': 4},
#   {'code': 'KW',
#    'name': 'Kuwait',
#    'locations': 1,
#    'firstUpdated': '2017-02-17 21:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['pm25'],
#    'count': 54958,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'KG',
#    'name': 'Kyrgyzstan',
#    'locations': 47,
#    'firstUpdated': '2019-03-08 20:00:00+00',
#    'lastUpdated': '2024-05-31 18:06:33.546+00',
#    'parameters': ['pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 188493,
#    'cities': 2,
#    'sources': 4},
#   {'code': 'LA',
#    'name': 'Laos',
#    'locations': 9,
#    'firstUpdated': '2021-04-29 19:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 227986,
#    'cities': 4,
#    'sources': 3},
#   {'code': 'LV',
#    'name': 'Latvia',
#    'locations': 13,
#    'firstUpdated': '2017-09-22 10:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 430248,
#    'cities': 5,
#    'sources': 2},
#   {'code': 'LT',
#    'name': 'Lithuania',
#    'locations': 17,
#    'firstUpdated': '2017-09-21 23:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 924030,
#    'cities': 13,
#    'sources': 2},
#   {'code': 'LU',
#    'name': 'Luxembourg',
#    'locations': 12,
#    'firstUpdated': '2017-09-22 10:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co', 'no', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 870723,
#    'cities': 1,
#    'sources': 2},
#   {'code': 'MK',
#    'name': 'Macedonia',
#    'locations': 28,
#    'firstUpdated': '2016-12-10 20:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co', 'no', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 2972749,
#    'cities': 6,
#    'sources': 2},
#   {'code': 'MG',
#    'name': 'Madagascar',
#    'locations': 1,
#    'firstUpdated': '2020-12-22 06:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['pm25'],
#    'count': 21959,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'MY',
#    'name': 'Malaysia',
#    'locations': 11,
#    'firstUpdated': '2016-04-05 09:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 115827,
#    'cities': 4,
#    'sources': 4},
#   {'code': 'ML',
#    'name': 'Mali',
#    'locations': 1,
#    'firstUpdated': '2020-03-16 05:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['pm25'],
#    'count': 25555,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'MX',
#    'name': 'Mexico',
#    'locations': 237,
#    'firstUpdated': '2016-03-06 19:00:00+00',
#    'lastUpdated': '2024-05-31 19:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'nox',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 10851220,
#    'cities': 111,
#    'sources': 4},
#   {'code': 'MD',
#    'name': 'Moldova',
#    'locations': 2,
#    'firstUpdated': '2020-04-20 19:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['no2', 'pm10', 'pm25', 'so2'],
#    'count': 35574,
#    'cities': 2,
#    'sources': 2},
#   {'code': 'MN',
#    'name': 'Mongolia',
#    'locations': 44,
#    'firstUpdated': '2016-01-30 00:15:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 2359003,
#    'cities': 23,
#    'sources': 4},
#   {'code': 'ME',
#    'name': 'Montenegro',
#    'locations': 9,
#    'firstUpdated': '2022-03-24 14:00:00+00',
#    'lastUpdated': '2024-03-19 22:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 273080,
#    'cities': 7,
#    'sources': 1},
#   {'code': 'MA',
#    'name': 'Morocco',
#    'locations': 2,
#    'firstUpdated': '2024-04-04 10:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 8904,
#    'cities': 0,
#    'sources': 1},
#   {'code': 'MZ',
#    'name': 'Mozambique',
#    'locations': 1,
#    'firstUpdated': '2024-01-18 18:00:00+00',
#    'lastUpdated': '2024-01-22 16:00:00+00',
#    'parameters': ['o3', 'pm25'],
#    'count': 137,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'MM',
#    'name': 'Myanmar',
#    'locations': 5,
#    'firstUpdated': '2016-01-30 01:00:00+00',
#    'lastUpdated': '2024-05-31 17:30:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 320480,
#    'cities': 3,
#    'sources': 4},
#   {'code': 'NP',
#    'name': 'Nepal',
#    'locations': 4,
#    'firstUpdated': '2017-03-02 23:15:00+00',
#    'lastUpdated': '2024-05-31 17:15:00+00',
#    'parameters': ['o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 222873,
#    'cities': 2,
#    'sources': 3},
#   {'code': 'NL',
#    'name': 'Netherlands',
#    'locations': 98,
#    'firstUpdated': '2016-01-30 01:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 13101369,
#    'cities': 50,
#    'sources': 4},
#   {'code': 'NZ',
#    'name': 'New Zealand',
#    'locations': 12,
#    'firstUpdated': '2023-03-31 15:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 99171,
#    'cities': 8,
#    'sources': 2},
#   {'code': 'NG',
#    'name': 'Nigeria',
#    'locations': 5,
#    'firstUpdated': '2019-04-26 08:00:00+00',
#    'lastUpdated': '2024-05-31 18:05:12.654+00',
#    'parameters': ['pm25'],
#    'count': 23730,
#    'cities': 2,
#    'sources': 3},
#   {'code': 'KP',
#    'name': 'North Korea',
#    'locations': 4,
#    'firstUpdated': '2024-03-20 08:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 30243,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'NO',
#    'name': 'Norway',
#    'locations': 354,
#    'firstUpdated': '2016-12-02 10:00:00+00',
#    'lastUpdated': '2024-05-31 18:44:00+00',
#    'parameters': ['bc',
#     'co',
#     'co2',
#     'humidity',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'pm4',
#     'pressure',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003',
#     'um005',
#     'um010',
#     'um025',
#     'um050',
#     'um100'],
#    'count': 36187746,
#    'cities': 27,
#    'sources': 5},
#   {'code': 'PK',
#    'name': 'Pakistan',
#    'locations': 6,
#    'firstUpdated': '2019-05-22 22:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['pm25'],
#    'count': 168687,
#    'cities': 4,
#    'sources': 5},
#   {'code': 'PS',
#    'name': 'Palestine',
#    'locations': 9,
#    'firstUpdated': '2017-08-10 23:00:00+00',
#    'lastUpdated': '2019-04-03 21:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'so2'],
#    'count': 1449100,
#    'cities': 0,
#    'sources': 1},
#   {'code': 'PY',
#    'name': 'Paraguay',
#    'locations': 1,
#    'firstUpdated': '2023-10-02 19:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['pm25'],
#    'count': 5128,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'PE',
#    'name': 'Peru',
#    'locations': 46,
#    'firstUpdated': '2016-03-04 17:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 2363656,
#    'cities': 21,
#    'sources': 5},
#   {'code': 'PH',
#    'name': 'Philippines',
#    'locations': 5,
#    'firstUpdated': '2023-09-06 20:00:00+00',
#    'lastUpdated': '2024-05-31 18:02:44.129+00',
#    'parameters': ['pm25', 'temperature'],
#    'count': 12900,
#    'cities': 1,
#    'sources': 3},
#   {'code': 'PL',
#    'name': 'Poland',
#    'locations': 331,
#    'firstUpdated': '2016-01-30 01:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['bc',
#     'co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 25858549,
#    'cities': 197,
#    'sources': 5},
#   {'code': 'PT',
#    'name': 'Portugal',
#    'locations': 70,
#    'firstUpdated': '2017-05-11 08:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 6864465,
#    'cities': 8,
#    'sources': 3},
#   {'code': 'PR',
#    'name': 'Puerto Rico',
#    'locations': 5,
#    'firstUpdated': '2016-05-04 11:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['o3', 'pm10', 'pm25'],
#    'count': 99760,
#    'cities': 2,
#    'sources': 1},
#   {'code': 'QA',
#    'name': 'Qatar',
#    'locations': 1,
#    'firstUpdated': '2022-04-11 14:00:00+00',
#    'lastUpdated': '2023-11-30 08:00:00+00',
#    'parameters': ['o3', 'pm25'],
#    'count': 16513,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'RO',
#    'name': 'Romania',
#    'locations': 318,
#    'firstUpdated': '2020-04-19 21:00:00+00',
#    'lastUpdated': '2024-05-31 18:06:38.617+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 5275200,
#    'cities': 109,
#    'sources': 4},
#   {'code': 'RU',
#    'name': 'Russia',
#    'locations': 54,
#    'firstUpdated': '2016-11-21 11:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 561138,
#    'cities': 2,
#    'sources': 5},
#   {'code': 'RW',
#    'name': 'Rwanda',
#    'locations': 2,
#    'firstUpdated': '2020-12-28 22:45:00+00',
#    'lastUpdated': '2024-05-14 00:00:00+00',
#    'parameters': ['co', 'no2', 'pm10', 'pm25'],
#    'count': 126004,
#    'cities': 1,
#    'sources': 2},
#   {'code': 'SA',
#    'name': 'Saudi Arabia',
#    'locations': 5,
#    'firstUpdated': '2019-07-15 19:00:00+00',
#    'lastUpdated': '2024-05-31 00:00:00+00',
#    'parameters': ['co', 'no2', 'pm10', 'pm25', 'so2'],
#    'count': 21342,
#    'cities': 3,
#    'sources': 3},
#   {'code': 'SN',
#    'name': 'Senegal',
#    'locations': 1,
#    'firstUpdated': '2023-09-05 08:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'temperature',
#     'um003'],
#    'count': 7574,
#    'cities': 0,
#    'sources': 1},
#   {'code': 'RS',
#    'name': 'Serbia',
#    'locations': 85,
#    'firstUpdated': '2017-09-22 09:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co', 'no2', 'o3', 'pm10', 'pm25', 'so2', 'temperature'],
#    'count': 3327150,
#    'cities': 44,
#    'sources': 5},
#   {'code': 'SK',
#    'name': 'Slovakia',
#    'locations': 85,
#    'firstUpdated': '2016-11-18 05:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co', 'no', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 5938390,
#    'cities': 58,
#    'sources': 3},
#   {'code': 'SI',
#    'name': 'Slovenia',
#    'locations': 39,
#    'firstUpdated': '2016-11-17 22:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 793207,
#    'cities': 26,
#    'sources': 3},
#   {'code': 'ZA',
#    'name': 'South Africa',
#    'locations': 200,
#    'firstUpdated': '2016-02-14 08:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'nox',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 4691551,
#    'cities': 36,
#    'sources': 4},
#   {'code': 'KR',
#    'name': 'South Korea',
#    'locations': 686,
#    'firstUpdated': '2020-10-12 06:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 6431385,
#    'cities': 3,
#    'sources': 3},
#   {'code': 'ES',
#    'name': 'Spain',
#    'locations': 738,
#    'firstUpdated': '2016-11-17 23:00:00+00',
#    'lastUpdated': '2024-05-31 18:44:00+00',
#    'parameters': ['co',
#     'humidity',
#     'no',
#     'no2',
#     'nox',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'pm4',
#     'pressure',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 45040033,
#    'cities': 352,
#    'sources': 7},
#   {'code': 'LK',
#    'name': 'Sri Lanka',
#    'locations': 1,
#    'firstUpdated': '2019-06-25 21:30:00+00',
#    'lastUpdated': '2024-05-30 18:30:00+00',
#    'parameters': ['pm25'],
#    'count': 21875,
#    'cities': 1,
#    'sources': 1},
#   {'code': 'SD',
#    'name': 'Sudan',
#    'locations': 3,
#    'firstUpdated': '2020-05-14 14:00:00+00',
#    'lastUpdated': '2023-05-17 13:00:00+00',
#    'parameters': ['pm25'],
#    'count': 54546,
#    'cities': 2,
#    'sources': 3},
#   {'code': 'SE',
#    'name': 'Sweden',
#    'locations': 170,
#    'firstUpdated': '2016-12-02 11:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co', 'no', 'no2', 'o3', 'pm10', 'pm25', 'so2'],
#    'count': 2549561,
#    'cities': 53,
#    'sources': 5},
#   {'code': 'CH',
#    'name': 'Switzerland',
#    'locations': 51,
#    'firstUpdated': '2016-11-21 12:00:00+00',
#    'lastUpdated': '2024-05-31 17:00:00+00',
#    'parameters': ['co',
#     'no',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 3298540,
#    'cities': 13,
#    'sources': 3},
#   {'code': 'TW',
#    'name': 'Taiwan',
#    'locations': 91,
#    'firstUpdated': '2016-12-20 19:00:00+00',
#    'lastUpdated': '2024-05-31 18:00:00+00',
#    'parameters': ['co',
#     'no2',
#     'o3',
#     'pm1',
#     'pm10',
#     'pm25',
#     'relativehumidity',
#     'so2',
#     'temperature',
#     'um003'],
#    'count': 8405956,
#    'cities': 17,
#    'sources': 2}]}
